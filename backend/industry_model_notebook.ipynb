# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("IndustryModelDataset.csv")
df.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  ...  Electricity(kWh) Electricity(kBtu)  \
# 0                    0659000030  ...      1.156514e+06         3946027.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    3376 non-null   int64
#  1   DataYear                         3376 non-null   int64
#  2   BuildingType                     3376 non-null   object
#  3   PrimaryPropertyType              3376 non-null   object
#  4   PropertyName                     3376 non-null   object
#  5   Address                          3376 non-null   object
#  6   City                             3376 non-null   object
#  7   State                            3376 non-null   object
#  8   ZipCode                          3360 non-null   float64
#  9   TaxParcelIdentificationNumber    3376 non-null   object
#  10  CouncilDistrictCode              3376 non-null   int64
#  11  Neighborhood                     3376 non-null   object
# ...

# %%
df = df.loc[:, ["NumberofFloors", "PropertyGFAParking", "PropertyGFABuilding(s)",
          "SiteEUI(kBtu/sf)", "SourceEUI(kBtu/sf)", "SteamUse(kBtu)", "Electricity(kBtu)",
          "NaturalGas(kBtu)", "TotalGHGEmissions"]]

df.dropna(inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3365 entries, 0 to 3375
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NumberofFloors          3365 non-null   int64
#  1   PropertyGFAParking      3365 non-null   int64
#  2   PropertyGFABuilding(s)  3365 non-null   int64
#  3   SiteEUI(kBtu/sf)        3365 non-null   float64
#  4   SourceEUI(kBtu/sf)      3365 non-null   float64
#  5   SteamUse(kBtu)          3365 non-null   float64
#  6   Electricity(kBtu)       3365 non-null   float64
#  7   NaturalGas(kBtu)        3365 non-null   float64
#  8   TotalGHGEmissions       3365 non-null   float64
# dtypes: float64(6), int64(3)
# memory usage: 262.9 KB

# %%
x_feat = [i for i in df.columns if i!= "TotalGHGEmissions"]
y_feat = "TotalGHGEmissions"

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.loc[:, x_feat], df[y_feat], test_size = 0.2)

x_train.head()
# Out:
#       NumberofFloors  PropertyGFAParking  PropertyGFABuilding(s)  \
# 1489               3                   0                   24032
# 1050               4                   0                  118154
# 1970               1                   0                   23100
# 3339               2                   0                   24990
# 1380               4                   0                   37485
#
#       SiteEUI(kBtu/sf)  SourceEUI(kBtu/sf)  SteamUse(kBtu)  Electricity(kBtu)  \
# 1489         23.600000           74.099998             0.0           566878.0
# 1050         42.500000          122.500000             0.0          3468864.0
# 1970        187.199997          338.799988             0.0          1572644.0
# 3339        176.899994          367.000000             0.0          2167029.0
# 1380         33.500000           85.199997             0.0           896658.0
#
#       NaturalGas(kBtu)
# 1489               0.0
# 1050          492034.0
# 1970         2751028.0
# ...

# %%
y_train.head()
# Out:
# 1489      3.95
# 1050     50.31
# 1970    157.07
# 3339    134.80
# 1380     25.36
# Name: TotalGHGEmissions, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(max_depth=100, random_state=0)

clf.fit(x_train, y_train)

print(f"Accuracy on test data: {clf.score(x_test, y_test)*100}%")
# Out:
# Accuracy on test data: 98.3843943723508%

# %%
import pickle

filename = "industry_RF_model.pickle"

# save model
pickle.dump(clf, open(filename, "wb"))

# %%
print(x_feat)
# Out:
# ['NumberofFloors', 'PropertyGFAParking', 'PropertyGFABuilding(s)', 'SiteEUI(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SteamUse(kBtu)', 'Electricity(kBtu)', 'NaturalGas(kBtu)']
